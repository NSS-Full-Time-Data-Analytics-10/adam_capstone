# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as BS
import numpy as np
import re
from datetime import datetime
import ast
import datetime as dt

# %%
file_paths = [
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\changing_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\unspecified_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\unknown_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\triangle_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\teardrop_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\star_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\sphere_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\rectangle_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\oval_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\other_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\orb_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\light_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\formation_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\flash_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\fireball_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\egg_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\disk_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\diamond_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\delta_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\cylinder_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\cube_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\cross_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\cone_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\circle_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\cigar_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\chevron_shape.csv"
]

dfs = [pd.read_csv(file_path) for file_path in file_paths]
concat_df = pd.concat(dfs, ignore_index=True)

# %%
concat_df.country = concat_df.country.str.lower()

# %%
concat_df = concat_df.loc[concat_df['country'] == 'usa']

# %%
ufo1 = pd.read_csv('ufo.csv')

# %%
len(concat_df)
# Out:
# 129570

# %%
len(ufo1)
# Out:
# 119014

# %%
concat_df.country.value_counts()
# Out:
# usa    129570
# Name: country, dtype: int64

# %%
concat_df = concat_df.reset_index(drop=True)

# %%
concat_df
# Out:
#                       date                                         reportlink  \
# 0      2023-07-28 21:40:00  https://nuforc.org/webreports/reports/177/S177...
# 1      2023-07-27 09:45:00  https://nuforc.org/webreports/reports/177/S177...
# 2      2023-07-26 23:42:00  https://nuforc.org/webreports/reports/177/S177...
# 3      2023-07-26 02:15:00  https://nuforc.org/webreports/reports/177/S177...
# 4      2023-07-25 23:15:00  https://nuforc.org/webreports/reports/176/S176...
# ...                    ...                                                ...
# 129565 2054-07-15 21:00:00  https://nuforc.org/webreports/reports/063/S636...
# 129566 2053-04-01 15:00:00  https://nuforc.org/webreports/reports/045/S450...
# 129567 2047-07-15 21:00:00  https://nuforc.org/webreports/reports/036/S361...
# 129568                 NaT  https://nuforc.org/webreports/reports/004/S040...
# 129569 2001-10-27 18:00:00  https://nuforc.org/webreports/reports/020/S200...
#
# ...

# %%
concat_df.date = pd.to_datetime(concat_df['date'], format='%m/%d/%y %H:%M', errors = 'coerce')

# %%
concat_df.date.dropna()
# Out:
# 0        2023-07-28 21:40:00
# 1        2023-07-27 09:45:00
# 2        2023-07-26 23:42:00
# 3        2023-07-26 02:15:00
# 4        2023-07-25 23:15:00
#                  ...
# 129564   2061-05-04 20:45:00
# 129565   2054-07-15 21:00:00
# 129566   2053-04-01 15:00:00
# 129567   2047-07-15 21:00:00
# 129569   2001-10-27 18:00:00
# Name: date, Length: 120672, dtype: datetime64[ns]

# %%
concat_df
# Out:
#                       date                                         reportlink  \
# 0      2023-07-28 21:40:00  https://nuforc.org/webreports/reports/177/S177...
# 1      2023-07-27 09:45:00  https://nuforc.org/webreports/reports/177/S177...
# 2      2023-07-26 23:42:00  https://nuforc.org/webreports/reports/177/S177...
# 3      2023-07-26 02:15:00  https://nuforc.org/webreports/reports/177/S177...
# 4      2023-07-25 23:15:00  https://nuforc.org/webreports/reports/176/S176...
# ...                    ...                                                ...
# 129565 2054-07-15 21:00:00  https://nuforc.org/webreports/reports/063/S636...
# 129566 2053-04-01 15:00:00  https://nuforc.org/webreports/reports/045/S450...
# 129567 2047-07-15 21:00:00  https://nuforc.org/webreports/reports/036/S361...
# 129568                 NaT  https://nuforc.org/webreports/reports/004/S040...
# 129569 2001-10-27 18:00:00  https://nuforc.org/webreports/reports/020/S200...
#
# ...

# %%
concat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129570 entries, 0 to 129569
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   date         120672 non-null  datetime64[ns]
#  1   reportlink   129570 non-null  object
#  2   city         129249 non-null  object
#  3   state        129100 non-null  object
#  4   country      129570 non-null  object
#  5   shape        123795 non-null  object
#  6   duration     123246 non-null  object
#  7   description  129502 non-null  object
#  8   post_date    129570 non-null  object
#  9   images       2314 non-null    object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 9.9+ MB

# %%
concat_df.date.isna().sum()
# Out:
# 8898

# %% [markdown]
# # CONCAT2

# %%
concat2 = concat_df

# %%
concat2['month'] = concat2['date'].dt.strftime('%B')
concat2['year'] = concat2['date'].dt.year
concat2['hour'] = concat2['date'].dt.hour

# %%
concat_df.shape = concat_df['shape'].str.lower()

# %%
concat_df.state = concat_df.state.str.upper()

# %%
concat_df = concat_df.reset_index(drop=True)

# %%
today = dt.datetime.today().date()

# %%
concat2.loc[concat['s']]
# Out:
#                       date                                         reportlink  \
# 0      2023-07-28 21:40:00  https://nuforc.org/webreports/reports/177/S177...
# 1      2023-07-27 09:45:00  https://nuforc.org/webreports/reports/177/S177...
# 2      2023-07-26 23:42:00  https://nuforc.org/webreports/reports/177/S177...
# 3      2023-07-26 02:15:00  https://nuforc.org/webreports/reports/177/S177...
# 4      2023-07-25 23:15:00  https://nuforc.org/webreports/reports/176/S176...
# ...                    ...                                                ...
# 129565 2054-07-15 21:00:00  https://nuforc.org/webreports/reports/063/S636...
# 129566 2053-04-01 15:00:00  https://nuforc.org/webreports/reports/045/S450...
# 129567 2047-07-15 21:00:00  https://nuforc.org/webreports/reports/036/S361...
# 129568                 NaT  https://nuforc.org/webreports/reports/004/S040...
# 129569 2001-10-27 18:00:00  https://nuforc.org/webreports/reports/020/S200...
#
# ...

# %%
# df = concat2[concat2['date'].dt.date <= today]

# %%
df = concat2

# %%
df.reset_index(drop = True)
# Out:
#                       date                                         reportlink  \
# 0      2023-07-28 21:40:00  https://nuforc.org/webreports/reports/177/S177...
# 1      2023-07-27 09:45:00  https://nuforc.org/webreports/reports/177/S177...
# 2      2023-07-26 23:42:00  https://nuforc.org/webreports/reports/177/S177...
# 3      2023-07-26 02:15:00  https://nuforc.org/webreports/reports/177/S177...
# 4      2023-07-25 23:15:00  https://nuforc.org/webreports/reports/176/S176...
# ...                    ...                                                ...
# 129565 2054-07-15 21:00:00  https://nuforc.org/webreports/reports/063/S636...
# 129566 2053-04-01 15:00:00  https://nuforc.org/webreports/reports/045/S450...
# 129567 2047-07-15 21:00:00  https://nuforc.org/webreports/reports/036/S361...
# 129568                 NaT  https://nuforc.org/webreports/reports/004/S040...
# 129569 2001-10-27 18:00:00  https://nuforc.org/webreports/reports/020/S200...
#
# ...

# %%
df.rename(columns = {'shape': 'shapes'}, inplace=True)

# %%
df.loc[df['shapes'] == 'other', 'reportlink'] = 'https://nuforc.org/webreports/' + df['reportlink']

# %%
df.loc[df['shapes'] == 'other']
# Out:
#                      date                                         reportlink  \
# 45422 2023-07-27 06:15:00  https://nuforc.org/webreports/reports/177/S177...
# 45423 2023-07-23 21:24:00  https://nuforc.org/webreports/reports/176/S176...
# 45424 2023-07-20 23:30:00  https://nuforc.org/webreports/reports/176/S176...
# 45425 2023-07-15 18:20:00  https://nuforc.org/webreports/reports/176/S176...
# 45426 2023-07-13 16:29:00  https://nuforc.org/webreports/reports/176/S176...
# ...                   ...                                                ...
# 54155                 NaT  https://nuforc.org/webreports/reports/147/S147...
# 54156                 NaT  https://nuforc.org/webreports/reports/148/S148...
# 54157                 NaT  https://nuforc.org/webreports/reports/034/S344...
# 54158                 NaT  https://nuforc.org/webreports/reports/163/S163...
# 54159                 NaT  https://nuforc.org/webreports/reports/163/S163...
#
# ...

# %%
df.city = df.city.str.replace('?', '')
# Out:
# C:\Users\Adam\AppData\Local\Temp\ipykernel_40048\976144747.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.city = df.city.str.replace('?', '')

# %%
df
# Out:
#                      date                                         reportlink  \
# 45422 2023-07-27 06:15:00  https://nuforc.org/webreports/reports/177/S177...
# 45423 2023-07-23 21:24:00  https://nuforc.org/webreports/reports/176/S176...
# 45424 2023-07-20 23:30:00  https://nuforc.org/webreports/reports/176/S176...
# 45425 2023-07-15 18:20:00  https://nuforc.org/webreports/reports/176/S176...
# 45426 2023-07-13 16:29:00  https://nuforc.org/webreports/reports/176/S176...
# ...                   ...                                                ...
# 54155                 NaT  https://nuforc.org/webreports/reports/147/S147...
# 54156                 NaT  https://nuforc.org/webreports/reports/148/S148...
# 54157                 NaT  https://nuforc.org/webreports/reports/034/S344...
# 54158                 NaT  https://nuforc.org/webreports/reports/163/S163...
# 54159                 NaT  https://nuforc.org/webreports/reports/163/S163...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129570 entries, 0 to 129569
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   date         120672 non-null  datetime64[ns]
#  1   reportlink   129570 non-null  object
#  2   city         129249 non-null  object
#  3   state        129100 non-null  object
#  4   country      129570 non-null  object
#  5   shapes       123795 non-null  object
#  6   duration     123246 non-null  object
#  7   description  129502 non-null  object
#  8   post_date    129570 non-null  object
#  9   images       2314 non-null    object
#  10  month        120672 non-null  object
#  11  year         120672 non-null  float64
#  12  hour         120672 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(10)
# memory usage: 12.9+ MB

# %%
ufo = pd.read_csv('backup.csv')

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129815 entries, 0 to 129814
# Data columns (total 15 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   date         129815 non-null  object
#  1   month        129815 non-null  object
#  2   year         129815 non-null  int64
#  3   reportlink   129815 non-null  object
#  4   city         129505 non-null  object
#  5   state        129352 non-null  object
#  6   country      129815 non-null  object
#  7   shapes       129815 non-null  object
#  8   duration     123497 non-null  object
#  9   description  129747 non-null  object
#  10  post_date    129815 non-null  object
#  11  images       2318 non-null    object
#  12  image_links  2238 non-null    object
#  13  lat          129055 non-null  float64
#  14  lng          129055 non-null  float64
# dtypes: float64(2), int64(1), object(12)
# memory usage: 14.9+ MB

# %%
ufo.loc[ufo['images'] == 'yes']
# Out:
#                   date      month  year  \
# 0       7/29/2023 0:00       July  2023
# 12      7/26/2023 0:00       July  2023
# 17      7/26/2023 0:00       July  2023
# 20      7/25/2023 0:00       July  2023
# 26      7/24/2023 0:00       July  2023
# ...                ...        ...   ...
# 127987  2/28/1968 0:00   February  1968
# 128762  6/21/1964 0:00       June  1964
# 129275   9/5/1957 0:00  September  1957
# 129517   8/1/1953 0:00     August  1953
# 129743  6/11/1947 0:00       June  1947
#
#                                                reportlink  \
# 0       https://nuforc.org/webreports/reports/177/S177...
# 12      https://nuforc.org/webreports/reports/177/S177...
# 17      https://nuforc.org/webreports/reports/177/S177...
# 20      https://nuforc.org/webreports/reports/176/S176...
# 26      https://nuforc.org/webreports/reports/176/S176...
# ...                                                   ...
# 127987  https://nuforc.org/webreports/reports/167/S167...
# ...

# %%
df.loc[df['images'] == 'Yes']
# Out:
#                       date                                         reportlink  \
# 2      2023-07-26 23:42:00  https://nuforc.org/webreports/reports/177/S177...
# 6      2023-07-23 21:26:00  https://nuforc.org/webreports/reports/176/S176...
# 13     2023-07-13 20:00:00  https://nuforc.org/webreports/reports/177/S177...
# 14     2023-07-12 21:13:00  https://nuforc.org/webreports/reports/176/S176...
# 15     2023-07-11 21:45:00  https://nuforc.org/webreports/reports/176/S176...
# ...                    ...                                                ...
# 128120 2021-11-19 03:15:00  https://nuforc.org/webreports/reports/166/S166...
# 128175 2020-07-15 02:00:00  https://nuforc.org/webreports/reports/175/S175...
# 128303 2018-04-16 22:25:00  https://nuforc.org/webreports/reports/171/S171...
# 128369 2017-03-28 16:37:00  https://nuforc.org/webreports/reports/173/S173...
# 128457 2015-11-20 21:00:00  https://nuforc.org/webreports/reports/174/S174...
#
# ...

# %%
df2['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d %H:%M:%S')
# Out:
# C:\Users\Adam\AppData\Local\Temp\ipykernel_40048\3864044316.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d %H:%M:%S')

# %%
ufo
# Out:
#                   date     month  year  \
# 0       7/29/2023 0:00      July  2023
# 1       7/28/2023 0:00      July  2023
# 2       7/28/2023 0:00      July  2023
# 3       7/28/2023 0:00      July  2023
# 4       7/28/2023 0:00      July  2023
# ...                ...       ...   ...
# 129810  2/15/1931 0:00  February  1931
# 129811  8/10/1930 0:00    August  1930
# 129812  6/30/1930 0:00      June  1930
# 129813  6/30/1930 0:00      June  1930
# 129814  6/12/1930 0:00      June  1930
#
#                                                reportlink  \
# 0       https://nuforc.org/webreports/reports/177/S177...
# 1       https://nuforc.org/webreports/reports/177/S177...
# 2       https://nuforc.org/webreports/reports/177/S177...
# 3       https://nuforc.org/webreports/reports/177/S177...
# 4       https://nuforc.org/webreports/reports/177/S177...
# ...                                                   ...
# 129810  https://nuforc.org/webreports/reports/037/S374...
# ...

# %%
backup = pd.merge(ufo, df[['reportlink', 'hour']], on='reportlink', how='inner', suffixes=('', '_df2'))

# %%
backup.to_csv('backup_merged.csv')

# %%
images = pd.read_csv(r'C:\Users\Adam\Documents\NSS\python\projects\ufo\data\imagelinks.csv')

# %%
images = images.drop('Unnamed: 0', axis=1)

# %%
#cconverts list to string comma separated

images['jpeg_links'] = images['jpeg_links'].apply(ast.literal_eval)

# Convert the list column to comma-separated strings
images['jpeg_links'] = images['jpeg_links'].apply(lambda x: ', '.join(x))

# %%
df2 = pd.merge(df2, images, how = 'left', left_on = 'reportlink', right_on = 'html_link')

# %%
df2 = df2.drop('html_link', axis=1)

# %%
df2.rename(columns = {'jpeg_links': 'image_links'}, inplace = True)

# %%
coords = pd.read_csv(r'C:\Users\Adam\Documents\NSS\python\projects\ufo\data\ufo_columns_lat_lng.csv', encoding='latin1')

# %%
coords
# Out:
#                      city state country        lat        lng
# 0           Gilbertsville    KY     usa  37.024495 -88.302493
# 1      Golden Pond (near)    KY     usa  36.785608 -88.024192
# 2         Goshen/Prospect    KY     usa  38.403318 -85.583077
# 3                 Gosport    KY     usa  37.839333 -84.270018
# 4             Grand Rives    KY     usa  37.003111 -88.234475
# ...                   ...   ...     ...        ...        ...
# 28327            Ft. Knox    KY     usa  37.883664 -85.965269
# 28328        Ft. Mitchell    KY     usa  39.047205 -84.559917
# 28329          Ft. Wright    KY     usa  39.051156 -84.535029
# 28330            Gamaliel    KY     usa  36.639778 -85.796644
# 28331             Garrett    KY     usa  37.479821 -82.831550
#
# [28332 rows x 5 columns]

# %%
df2 = pd.merge(df2, coords, how='inner', on=(['city', 'state']))

# %%
df2.rename(columns = {'country_x': 'country'}, inplace = True)

# %%
df2 = df2.drop('country_y', axis=1)

# %%
# df2.to_csv('ufo.csv')

# %%
original = original.drop('Unnamed: 0', axis=1)

# %%
merged = pd.merge(original, df2, how='inner', on='reportlink', suffixes=('', '_df2'))

# %%
merged
# Out:
#               date     month  year  \
# 0        7/27/2023      July  2023
# 1        7/26/2023      July  2023
# 2        7/25/2023      July  2023
# 3        7/23/2023      July  2023
# 4        7/22/2023      July  2023
# ...            ...       ...   ...
# 120301   7/15/1975      July  1975
# 120302  11/15/1974  November  1974
# 120303   3/24/1972     March  1972
# 120304   7/22/1971      July  1971
# 120305   4/17/1970     April  1970
#
#                                                     reportlink          city  \
# 0       https://nuforc.org/webreports/reports/177/S177048.html    Plainfield
# 1       https://nuforc.org/webreports/reports/177/S177053.html  Little Falls
# 2       https://nuforc.org/webreports/reports/177/S177081.html    sacramento
# 3       https://nuforc.org/webreports/reports/176/S176930.html        Buford
# 4       https://nuforc.org/webreports/reports/176/S176927.html    Bellefonte
# ...

# %%
merged.loc[merged['images'] == 'yes']
# Out:
#               date    month  year  \
# 3        7/23/2023     July  2023
# 5        7/20/2023     July  2023
# 21        6/1/2023     June  2023
# 23       5/27/2023      May  2023
# 28       5/19/2023      May  2023
# ...            ...      ...   ...
# 119249    8/8/2022   August  2022
# 119251    8/2/2022   August  2022
# 119256   5/23/2022      May  2022
# 119258    4/5/2022    April  2022
# 119286  10/19/2020  October  2020
#
#                                                     reportlink  \
# 3       https://nuforc.org/webreports/reports/176/S176930.html
# 5       https://nuforc.org/webreports/reports/176/S176895.html
# 21      https://nuforc.org/webreports/reports/176/S176087.html
# 23      https://nuforc.org/webreports/reports/176/S176628.html
# 28      https://nuforc.org/webreports/reports/175/S175838.html
# ...                                                        ...
# 119249  https://nuforc.org/webreports/reports/170/S170987.html
# ...

# %%
merged.to_csv('dontdelete.csv')

# %%
dontdelete = pd.read_csv('dontdelete.csv')

# %%
dontdelete
# Out:
#                     date  year     month  hour  \
# 0        7/27/2023 14:20  2023      July    14
# 1        7/26/2023 22:10  2023      July    22
# 2         7/25/2023 2:05  2023      July     2
# 3         7/23/2023 2:27  2023      July     2
# 4        7/22/2023 21:30  2023      July    21
# ...                  ...   ...       ...   ...
# 120301    7/15/1975 9:30  1975      July     9
# 120302  11/15/1974 23:30  1974  November    23
# 120303   3/24/1972 20:30  1972     March    20
# 120304    7/22/1971 0:15  1971      July     0
# 120305   4/17/1970 19:00  1970     April    19
#
#                                                     reportlink          city  \
# 0       https://nuforc.org/webreports/reports/177/S177048.html    Plainfield
# 1       https://nuforc.org/webreports/reports/177/S177053.html  Little Falls
# 2       https://nuforc.org/webreports/reports/177/S177081.html    sacramento
# 3       https://nuforc.org/webreports/reports/176/S176930.html        Buford
# ...
