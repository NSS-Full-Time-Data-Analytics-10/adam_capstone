# %%
import pandas as pd

# %%
# get image tags from ufo site

def get_images_from_webpage(url):
    response = requests.get(url)
    images = []
    soup = BeautifulSoup(response.text, 'html.parser')
    img_tags = soup.find_all('img')

    for img_tag in img_tags:
        img_url = img_tag.get('src')
        if img_url.startswith('//'):
            img_url = 'http:' + img_url
        elif img_url.startswith('/'):
            img_url = '/'.join(url.split('/')[:3]) + img_url

        images.append(img_url)

    return images

# %%
# use google maps to get the lat, lng coordinates based on city/state/country data
import requests
import csv
from bs4 import BeautifulSoup
import os
import time

GOOGLE_API_KEY = 'AIzaSyBb0p5xjBZMescIWTBpJfhPW-AjgCMPLFU'
input_csv_file = 'ufo_columns_first.csv'
output_csv_file = 'ufocolumns_lat_lng.csv'

# connect
def extract_lat_long_via_address(address):
    lat, lng = None, None
    api_key = GOOGLE_API_KEY
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"
    endpoint = f"{base_url}?address={address}&key={api_key}"

    r = requests.get(endpoint)
    if r.status_code not in range(200, 299):
        return None, None
    try:
        results = r.json()['results'][0]
        lat = results['geometry']['location']['lat']
        lng = results['geometry']['location']['lng']
    except:
        print(f'Error: {address}') # if there is an issue print the offender
        pass
    return lat, lng


# Create a list to store the updated rows
updated_rows = []

with open(input_csv_file, 'r', newline='', encoding='utf-8') as file:
    # Create a CSV reader object
    reader = csv.reader(file)

    # Read the header row and store it (if any)
    header = next(reader)
    header += ['lat', 'lng']

    # print the length of the reader
    reader = list(reader)
    print(len(reader))

    count = 0
    # Loop through each row in the CSV file
    for row in reader:
        count += 1
        city = row[0]
        state = row[1]
        country = row[2]
#         date = row[0]
#         month = row[1]
#         year = row[2]
#         reportlink = row[3]
#         shape = row[7]
#         duration = row[8]
#         description = row[9]
#         post_date = row[10]
#         images = row[11]

        address = f"{city}, {state}, {country}"

        # Call the function to get the latitude and longitude
        result = extract_lat_long_via_address(address)

        # Append the latitude and longitude to the original row
        row += result

        # Add the updated row to the list of updated rows
        updated_rows.append(row)
        
        time.sleep(.08) # wait time before runnning again (google maps 50 requests/second cap)
    print('Looped through {} rows'.format(count))

# Write the updated data back to the CSV file
with open(output_csv_file, 'w', newline='', errors='ignore') as file:
    writer = csv.writer(file)

    # Write the header row (if any)
    if header:
        writer.writerow(header)

    # Write the modified rows (including latitude and longitude)
    writer.writerows(updated_rows)

print("CSV file updated successfully.")
# Out:
# 18362
# Error: Harrison & Mt.Plesent (between), MI, usa
# Error: Randolph (near; 19 & 56), MN, usa
# Error: Bolivar - 170th & 326th Road junction, MO, usa
# Error: Sullivan & Fenton, MO, usa
# Error: I-10 (MM# 15; 10 mi. N of MS), MS, usa
# Error: Vass (Town of, on hwy #1), NC, usa
# Error: Ocean & Monmouth Counties, NJ, usa
# Error: Verhalen (between Balmorea & Pecos, TX, usa
# Looped through 18362 rows
# CSV file updated successfully.
