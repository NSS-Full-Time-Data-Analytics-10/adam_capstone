# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as BS
import numpy as np
import re
pd.set_option('display.max_colwidth', None)
from datetime import datetime

# %% [markdown]
# <span style='background:purple; font-size:25px'>individual csv files</span>

# %%
# triangle = pd.read_csv('data/triangle_shape.csv')
# unknown_shape = pd.read_csv('data/unknown_shape.csv')
# unspecified_shape = pd.read_csv('data/unspecified_shape.csv')
# changing_shape = pd.read_csv('data/changing_shape.csv')
# chevron_shape = pd.read_csv('data/chevron_shape.csv')
# cigar_shape = pd.read_csv('data/cigar_shape.csv')
# circle_shape = pd.read_csv('data/circle_shape.csv')
# cone_shape = pd.read_csv('data/cone_shape.csv')
# cross_shape = pd.read_csv('data/cross_shape.csv')
# cube_shape = pd.read_csv('data/cube_shape.csv')
# cylinder_shape = pd.read_csv('data/cylinder_shape.csv')
# delta_shape = pd.read_csv('data/delta_shape.csv')
# diamond_shape = pd.read_csv('data/diamond_shape.csv')
# disk_shape = pd.read_csv('data/disk_shape.csv')
# egg_shape = pd.read_csv('data/egg_shape.csv')
# fireball_shape = pd.read_csv('data/fireball_shape.csv')
# flash_shape = pd.read_csv('data/flash_shape.csv')
# formation_shape = pd.read_csv('data/formation_shape.csv')
# light_shape = pd.read_csv('data/light_shape.csv')
# orb_shape = pd.read_csv('data/orb_shape.csv')
# other_shape = pd.read_csv('data/other_shape.csv')
# oval_shape = pd.read_csv('data/oval_shape.csv')
# rectangle_shape = pd.read_csv('data/rectangle_shape.csv')
# sphere_shape = pd.read_csv('data/sphere_shape.csv')
# star_shape = pd.read_csv('data/star_shape.csv')
# teardrop_shape = pd.read_csv('data/teardrop_shape.csv')

# %% [markdown]
# <span style='background:purple; font-size:25px'>combining individual files into 1</span>

# %%
# df_list = [triangle, unknown_shape, unspecified_shape, changing_shape,
#                    chevron_shape, cigar_shape, circle_shape, cone_shape,
#                    cross_shape, cube_shape, cylinder_shape, delta_shape,
#                    diamond_shape, disk_shape, egg_shape, fireball_shape,
#                    flash_shape, formation_shape, light_shape, orb_shape,
#                    other_shape, oval_shape, rectangle_shape, sphere_shape,
#                    star_shape, teardrop_shape]

# %%
# ufo = pd.concat(df_list)

# %%
# ufo.to_csv('ufo.csv', index = False)

# %% [markdown]
# <span style='background:purple; font-size:25px'>read in the full (cleaned) dataset csv</span>

# %%
ufo = pd.read_csv('data/ufo.csv')

# %%
ufo.shape
# Out:
# (145202, 14)

# %%
# convert date column to datetime and create year/month

# %%
ufo.date = pd.to_datetime(ufo['date'], errors = 'coerce')

# %%
ufo.dropna(subset=['date'], inplace=True) # drop rows with none/invalid dates

# %%
current_date = pd.Timestamp(datetime.now())

ufo = ufo[ufo['date'] <= current_date] # get rid of rows with dates after today

# %%
ufo['months'] = ufo.date.dt.strftime('%B') # create month column using months name

# %%
ufo.insert(1, 'month', ufo.months) # move month column to after date

# %%
ufo.drop('months', axis=1, inplace=True) # drop old months column

# %%
ufo['years'] = ufo['date'].dt.year.astype(int) # create years column as int

# %%
ufo.insert(2, 'year', ufo.years)

# %%
ufo.drop('years', axis=1, inplace=True)

# %%
ufo.head(2)

# %% [markdown]
# # create cleaned csv

# %%
# ufo.to_csv('ufo.csv', index = False)

# %%
ufo
# Out:
#              date  month  year  \
# 0       7/29/2023   July  2023
# 1       7/27/2023   July  2023
# 2       7/26/2023   July  2023
# 3       7/25/2023   July  2023
# 4       7/23/2023   July  2023
# ...           ...    ...   ...
# 145197   6/1/1961   June  1961
# 145198  7/10/1958   July  1958
# 145199  6/30/1958   June  1958
# 145200  6/30/1957   June  1957
# 145201   4/9/1957  April  1957
#
#                                                     reportlink           city  \
# 0       https://nuforc.org/webreports/reports/177/S177093.html        Mallusk
# 1       https://nuforc.org/webreports/reports/177/S177048.html     Plainfield
# 2       https://nuforc.org/webreports/reports/177/S177053.html   Little Falls
# 3       https://nuforc.org/webreports/reports/177/S177081.html     sacramento
# 4       https://nuforc.org/webreports/reports/176/S176930.html         Buford
# ...                                                        ...            ...
# ...

# %%
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\chevron_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\changing_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\unspecified_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\unknown_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\triangle_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\teardrop_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\star_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\sphere_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\rectangle_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\oval_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\other_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\orb_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\light_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\formation_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\flash_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\fireball_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\egg_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\disk_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\diamond_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\delta_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\cylinder_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\cube_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\cross_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\cone_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\circle_shape.csv"
"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\cigar_shape.csv"

# %%
# List of file paths
file_paths = [
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\chevron_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\changing_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\unspecified_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\unknown_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\triangle_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\teardrop_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\star_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\sphere_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\rectangle_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\oval_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\other_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\orb_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\light_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\formation_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\flash_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\fireball_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\egg_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\disk_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\diamond_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\delta_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\cylinder_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\cube_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\cross_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\cone_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\circle_shape.csv",
    r"C:\Users\Adam\Documents\NSS\python\projects\ufo\data\cigar_shape.csv"
]

# Create an empty list to store DataFrames
dataframes = []

# Loop through file paths and read CSVs into DataFrames
for file_path in file_paths:
    df = pd.read_csv(file_path)
    dataframes.append(df)

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_df['shape'] = combined_df['shape'].str.lower()

# %%
combined_df.loc[combined_df['shape'] == 'other']
# Out:
#                 date                reportlink                 city     state  \
# 52548  7/27/23 06:15  reports/177/S177039.html               Dawson        WV
# 52549  7/23/23 21:24  reports/176/S176912.html                Noble        OK
# 52550  7/20/23 23:30  reports/176/S176955.html                 Yelm        WA
# 52551  7/20/23 20:31  reports/176/S176952.html        St Catharines        ON
# 52552  7/17/23 01:15  reports/176/S176821.html            Elvanfoot  Scotland
# ...              ...                       ...                  ...       ...
# 62500            NaN  reports/148/S148478.html              Nahunta        GA
# 62501            NaN   reports/084/S84341.html  VÃ¤sterÃ¥s (Sweden)       NaN
# 62502            NaN   reports/034/S34436.html             Key West        FL
# 62503            NaN  reports/163/S163863.html            Shoreline        WA
# 62504            NaN  reports/163/S163796.html            Rockville        MD
#
# ...

# %%
text_to_add = 'https://nuforc.org/webreports/'

# Update rows where shape is 'Other'
combined_df.loc[combined_df['shape'] == 'Other', 'shape'] = text_to_add + combined_df.loc[combined_df['shape'] == 'Other', 'shape']

# Print the modified DataFrame
# Out:
#                             date  \
# 0                  7/18/23 03:15
# 1                  7/10/23 22:00
# 2                   7/3/23 23:00
# 3                  6/30/23 14:00
# 4                  6/28/23 00:47
# ...                          ...
# 145554           summer/49 11:00
# 145555  spring/summer/1995 08:00
# 145556           7/19?2019 07:45
# 145557            12/24/98 06:24
# 145558               DITTO 03:00
#
#                                                     reportlink  \
# 0       https://nuforc.org/webreports/reports/176/S176823.html
# 1       https://nuforc.org/webreports/reports/176/S176725.html
# 2       https://nuforc.org/webreports/reports/176/S176578.html
# 3       https://nuforc.org/webreports/reports/176/S176555.html
# 4       https://nuforc.org/webreports/reports/176/S176500.html
# ...                                                        ...
# 145554   https://nuforc.org/webreports/reports/009/S09687.html
# ...

# %%
second_df = combined_df

# %%
second_df.loc[second_df['shape'] == 'other', 'reportlink'] = 'https://nuforc.org/webreports/' + second_df['reportlink']

# %%
second_df.loc[second_df['shape'] == 'other']
# Out:
#                 date                                              reportlink  \
# 52548  7/27/23 06:15  https://nuforc.org/webreports/reports/177/S177039.html
# 52549  7/23/23 21:24  https://nuforc.org/webreports/reports/176/S176912.html
# 52550  7/20/23 23:30  https://nuforc.org/webreports/reports/176/S176955.html
# 52551  7/20/23 20:31  https://nuforc.org/webreports/reports/176/S176952.html
# 52552  7/17/23 01:15  https://nuforc.org/webreports/reports/176/S176821.html
# ...              ...                                                     ...
# 62500            NaN  https://nuforc.org/webreports/reports/148/S148478.html
# 62501            NaN   https://nuforc.org/webreports/reports/084/S84341.html
# 62502            NaN   https://nuforc.org/webreports/reports/034/S34436.html
# 62503            NaN  https://nuforc.org/webreports/reports/163/S163863.html
# 62504            NaN  https://nuforc.org/webreports/reports/163/S163796.html
#
# ...

# %%
main = pd.read_excel(r'C:\Users\Adam\Downloads\NSS\python\projects\added_data.xlsx', sheet_name = 'main')

# %%
joined_df = pd.merge(main, second_df, how = 'left', on = 'reportlink')
# Out:
#             id       date  hour  day    month    year  \
# 0        15153 1970-01-01   NaN  Thu  January  1970.0
# 1        15295 1970-01-01  13.0  Thu  January  1970.0
# 2        49928 1970-01-01   2.0  Thu  January  1970.0
# 3       103948 1970-01-01   NaN  Thu  January  1970.0
# 4       105061 1970-01-05  22.0  Mon  January  1970.0
# ...        ...        ...   ...  ...      ...     ...
# 125657  126569 2005-06-29   NaN  NaN      NaN     NaN
# 125658  126570 2008-12-12   NaN  NaN      NaN     NaN
# 125659  126571 2009-08-14   NaN  NaN      NaN     NaN
# 125660  126572 2009-11-06   NaN  NaN      NaN     NaN
# 125661  126573 2016-11-11   NaN  NaN      NaN     NaN
#
#                                                     reportlink  \
# 0        https://nuforc.org/webreports/reports/019/S19365.html
# 1       https://nuforc.org/webreports/reports/160/S160087.html
# 2        https://nuforc.org/webreports/reports/075/S75909.html
# ...

# %%
columns_to_keep = ['reportlink', 'date']

joined_df = pd.merge(main, second_df[columns_to_keep], how='left', on='reportlink', suffixes = ('', '_df'))

# %%
joined_df
# Out:
#             id       date  hour  day    month    year  \
# 0        15153 1970-01-01   NaN  Thu  January  1970.0
# 1        15295 1970-01-01  13.0  Thu  January  1970.0
# 2        49928 1970-01-01   2.0  Thu  January  1970.0
# 3       103948 1970-01-01   NaN  Thu  January  1970.0
# 4       105061 1970-01-05  22.0  Mon  January  1970.0
# ...        ...        ...   ...  ...      ...     ...
# 125657  126569 2005-06-29   NaN  NaN      NaN     NaN
# 125658  126570 2008-12-12   NaN  NaN      NaN     NaN
# 125659  126571 2009-08-14   NaN  NaN      NaN     NaN
# 125660  126572 2009-11-06   NaN  NaN      NaN     NaN
# 125661  126573 2016-11-11   NaN  NaN      NaN     NaN
#
#                                                     reportlink  \
# 0        https://nuforc.org/webreports/reports/019/S19365.html
# 1       https://nuforc.org/webreports/reports/160/S160087.html
# 2        https://nuforc.org/webreports/reports/075/S75909.html
# ...

# %%
joined_df2.to_excel('fixed_date.xlsx', index=False, engine='openpyxl')

# %%
joined_df2 = joined_df

# %%
joined_df2['date_df'] = pd.to_datetime(joined_df2['date_df'], errors='coerce')

joined_df2['hour_column'] = joined_df2['date_df'].dt.strftime('%H:%M')

# %%
ufo_main = pd.read_excel(r"C:\Users\Adam\Downloads\NSS\python\projects\filtered_dates.xlsx", sheet_name = 'main')

# %%
result = pd.DataFrame()

# %%
result = ufo_main.groupby('date')['city'].value_counts()

# %%
result
# Out:
# date        city
# 1970-01-01  Grand Rapids    1
#             Joplin          1
#             Raymond         1
#             Telford         1
# 1970-01-05  Candia          1
#                            ..
# 2023-07-28  Gainesville     1
#             Leesburg        1
#             Northvale       1
#             Sioux falls     1
# 2023-07-29  Riverview       1
# Name: city, Length: 119075, dtype: int64
